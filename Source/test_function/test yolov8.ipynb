# %%
a = [     1326.4   ,   851.29   ,   1551.9   ,   1027.9]
b = [     1378.8   ,   785.47   ,   1506.9    ,  989.19]
def check_for_overlap(a, b):
    rectangle_a  = {"x1":a[0], "y1":a[1], "x2":a[2],"y2":a[3]}
    rectangle_b  = {"x1":b[0], "y1":b[1], "x2":b[2], "y2":b[3]}
    #black color                           or    red color
    if(rectangle_a["y1"]<rectangle_b["y2"] or rectangle_a["x1"]<rectangle_b["x2"]):
        print("no overlap ")
    #the blue color                          or   green 
    elif(rectangle_a["x2"]>rectangle_b["x1"] or rectangle_a["y2"]>rectangle_b["y1"]):
        print("no overlap ")
    else:
        print("YES ! there is a overlap")

check_for_overlap(a, b)
# Out:
# no overlap

# %%
def overlap(rec1, rec2):
	if (rec2[2] > rec1[0] and rec2[2] < rec1[2]) or \
		(rec2[0] > rec1[0] and rec2[0] < rec1[2]):
		x_match = True
	else:
		x_match = False
	if (rec2[3] > rec1[1] and rec2[3] < rec1[3]) or \
		(rec2[1] > rec1[1] and rec2[1] < rec1[3]):
		y_match = True
	else:
		y_match = False
	if x_match and y_match:
		return True
	else:
		return False
	
a = [     1397.3   ,   781.44   ,   1517.4    ,  986.21]
b = [     1336.2   ,   850.14    ,  1563.7    ,  1026.3]

overlap(a, b)
# Out:
# False

# %%
from shapely.geometry import Polygon
import numpy as np

rect1=np.array([     1397.3   ,   781.44   ,   1517.4    ,  986.21])
rect2=np.array([     1336.2   ,   850.14     , 1563.7   ,   1026.3])

def overlap2(rect1,rect2):
    p1 = Polygon([(rect1[0],rect1[1]), (rect1[1],rect1[1]),(rect1[2],rect1[3]),(rect1[2],rect1[1])])
    p2 = Polygon([(rect2[0],rect2[1]), (rect2[1],rect2[1]),(rect2[2],rect2[3]),(rect2[2],rect2[1])])
    return(p1.intersects(p2))

print(overlap2(rect1,rect2))
# Out:
# True

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Set the figure size
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True

# Make a list of columns
columns = ['           test','         train']

# Read a CSV file
df = pd.read_csv("/Users/acemitto/Desktop/STUDY/ACE/CAPSTONE/vietnamese-traffic-system/runs/detect/train/results.csv", usecols=columns)

# Plot the lines
df.plot()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Set the figure size
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True

# Make a list of columns
columns = ['   train','       test']

# Read a CSV file
df = pd.read_csv("/Users/acemitto/Desktop/STUDY/ACE/CAPSTONE/vietnamese-traffic-system/runs/detect/train/results.csv", usecols=columns)

# Plot the lines
df.plot()
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.show()
